# %%
# there defined properties of used objects
###
{i#, j#}::Indices(name=vector, position=independent).
{i#, j#}::Integer(1..N).

{M,N,K,L,P,Q,R,S,T,U,V, M#,N#}::Indices(name=curv27e6, position=independent).
{m,n,k,l,p,q,r,t,u,v,m#,n#}::Indices(name=curv6, parent=curv27e6, position=independent).

{A,B,C,E,F,H, A#,B#}::Indices(name=flat27e6, position=independent).
{a,b,c,d,e,f,g,h,a#,b#}::Indices(name=flat6, parent=flat27e6, position=independent).
{\alpha,\beta,\gamma,\delta,\lambda ,\alpha#,\beta#,\lambda#}::Indices(name=flat15, position=independent).

{M,N,K,L,P,Q,R,S,T,U,V, M#,N#}::Integer(1..27).
{m,n,k,l,p,q,r,t,u,v,m#,n#}::Integer(1..5).

{A,B,C,E,F,H, A#,B#}::Integer(1..27).
{a,b,c,d,e,f,g,h,a#,b#}::Integer(1..5).
{\alpha,\lambda, \beta,\gamma,\delta,\alpha#,\beta#,\lambda#}::Integer(1..2).


Z^{A B}_{C}::TableauSymmetry(shape={2}, indices={0,1}).
E^{m n}_{ A}::TableauSymmetry(shape={1,1}, indices={0,1}).
E_{m n}^{ A}::TableauSymmetry(shape={1,1}, indices={0,1}).

d^{M N}_{m n}::TableauSymmetry(shape={2}, indices={0,1}, shape={1,1}, indices={2,3}).
d_{M N}^{m n}::TableauSymmetry(shape={2}, indices={0,1}, shape={1,1}, indices={2,3}).
d_{M}^{p l m n}::TableauSymmetry(shape={1,1}, indices={1,2}, shape={1,1}, indices={3,4}).

d_{M N K}::Symmetric:
d^{M N K}::Symmetric:
de_{M N K}::Symmetric:
de^{M N K}::Symmetric:


\partial{#}::PartialDerivative.
\nabla{#}::Derivative.
D{#}::Derivative.
\delta{#}::KroneckerDelta.
\epsilon{#}::EpsilonTensor(delta=\delta{#});

\Omega^{m n k}::AntiSymmetric:
\epsilon_{\alpha# \beta#}::AntiSymmetric:
\epsilon_{\gamma \delta}::AntiSymmetric:
\rho_{\alpha}^{ i1 i2 }::TableauSymmetry(shape={1,1}, indices={1,2}).
\epsilon{#}::EpsilonTensor( delta = \delta ):
\epsilon_{k# l# m# n# p#}::AntiSymmetric:
\epsilon^{k# l# m# n# p#}::AntiSymmetric:
\epsilon^{i1 i2 i3 i4}::AntiSymmetric:
\epsilon^{i5 i6 i7 i8}::AntiSymmetric:

\partial{#}::WeightInherit(label=all, type=additive):

{w_{m},\Omega{#}, W_{em m n}, \rho^{i1 i2 i3}}::Weight(label=w, value=1):
{g{#}, ge{#}}::Weight(label=g, value=1):
{J, \rho^{i1 i2 i3 i4 i5 i6}}::Weight(label=J, value=1):
\epsilon{#}::Weight(label=e, value=1):
# Out:
# ${}\text{Property EpsilonTensor attached to}\epsilon\left(\#\right).$

# %%
# there defined Z-tensor, where e_{mod}= e \exp{-3 \phi}, where e - veilbein of internal space
###
Z :=  5 * e_{mod} d_{A B E} d^{N M K} G_{N}^{C} \partial_{M}{G_{K}^{E}} 
       +  5 * d_{A B E} d^{N M K} G_{N}^{C} G_{K}^{E} \partial_{M}{e_{mod}};
# Out:
# ${}5e_{mod} d_{A B E} d^{N M K} G_{N}\,^{C} \partial_{M}{G_{K}\,^{E}}+5d_{A B E} d^{N M K} G_{N}\,^{C} G_{K}\,^{E} \partial_{M}{e_{mod}}$

# %%
# there defined rotation of generalised veilbein by for-vector tensor of deformation
###
substitute(_,$G_{M#}^{A#} -> E_{M#}^{A#} + \Omega_{M#}^{N} E_{N}^{A#}$)
distribute(_)
product_rule(_)
distribute(_)
sort_product(_)
rename_dummies(_)
drop_weight(_,$w=0$);
# Out:
# ${}5E_{M}\,^{C} E_{N}\,^{E} \partial_{L}{\Omega_{K}\,^{N}} d_{A B E} d^{M L K} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{N} \partial_{L}{E_{N}\,^{E}} d_{A B E} d^{M L K} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{M} \partial_{L}{E_{N}\,^{E}} d_{A B E} d^{K L N} e_{mod}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{M} \partial_{P}{\Omega_{L}\,^{N}} d_{A B E} d^{K P L} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{N} \Omega_{L}\,^{M} \partial_{P}{E_{N}\,^{E}} d_{A B E} d^{L P K} e_{mod}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{N} \partial_{L}{e_{mod}} d_{A B E} d^{M L K}+5E_{M}\,^{E} E_{N}\,^{C} \Omega_{K}\,^{N} \partial_{L}{e_{mod}} d_{A B E} d^{K L M}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{N} \Omega_{L}\,^{M} \partial_{P}{e_{mod}} d_{A B E} d^{L P K}$

# %%
#usage of section constraint
###
substitute(_,$d^{M L K}->d^{L M K}$)
substitute(_,$\partial_{L}{A??}d^{L M K}->\partial_{l}{A??}d^{l M K}$)
rename_dummies(_);
# Out:
# ${}5E_{M}\,^{C} E_{N}\,^{E} \partial_{m}{\Omega_{K}\,^{N}} d^{m M K} d_{A B E} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{N} \partial_{m}{E_{N}\,^{E}} d^{m M K} d_{A B E} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{M} \partial_{m}{E_{N}\,^{E}} d^{m K N} d_{A B E} e_{mod}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{M} \partial_{m}{\Omega_{L}\,^{N}} d^{m K L} d_{A B E} e_{mod}+5E_{M}\,^{C} \Omega_{K}\,^{N} \Omega_{L}\,^{M} \partial_{m}{E_{N}\,^{E}} d^{m L K} d_{A B E} e_{mod}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{N} \partial_{m}{e_{mod}} d^{m M K} d_{A B E}+5E_{M}\,^{E} E_{N}\,^{C} \Omega_{K}\,^{N} \partial_{m}{e_{mod}} d^{m K M} d_{A B E}+5E_{M}\,^{C} E_{N}\,^{E} \Omega_{K}\,^{N} \Omega_{L}\,^{M} \partial_{m}{e_{mod}} d^{m L K} d_{A B E}$

# %%
# branching of generalised indices and substituting of precise view of d-tensor
substitute(_,$\Omega_{M}^{N} -> gma_{M m \alpha} Om^{m \alpha n} gm_{n}^{N} + gnnm_{M}^{m1 m2} Om_{m1 m2}^{n} gm_{n}^{N} + ga_{M \alpha} Om^{ n \alpha} gm_{n}^{N}  + gnnm_{M}^{m1 m2} Om_{m1 m2 n \beta} gma^{n \beta N} + ga_{M \alpha} Om^{\alpha}_{n \beta} gma^{n \beta N}+ ga_{M \alpha} Om^{\alpha n1 n2}gnnm_{n1 n2}^{ N}  $)
distribute(_)
product_rule(_)
distribute(_)
distribute(_)
distribute(_)
substitute(_,$\partial^{A??}{ gm{#}} -> 0$)
substitute(_,$\partial^{A??}{ gnnm{#}} -> 0$)
substitute(_,$\partial^{A??}{ gma{#}} -> 0$)
substitute(_,$\partial^{A??}{ ga{#}} -> 0$)
substitute(_,$d^{m# K L}gnnm_{K}^{k# l#} ga_{L \gamma#}->0$)
substitute(_,$d^{m# L K}gnnm_{K}^{k# l#} ga_{L \gamma#}->0$)
substitute(_,$d^{m# M N}gam_{M  k# \alpha#}gam_{N l# \beta#}->0$)
substitute(_,$d^{m# M N}gma_{M  k# \alpha#}gma_{N l# \beta#}->0$)
substitute(_,$d^{m# N M}gma_{M  k# \alpha#}gma_{N l# \beta#}->0$)
substitute(_,$d^{m# K L}ga_{K \alpha# }ga_{L \gamma# }->0$)
substitute(_,$d^{q# N K}gma_{N p \beta} gnnm_{K}^{n k}->0$)
substitute(_,$d^{q# N K}gma_{K n \alpha} gnnm_{N}^{k l}->0$)
substitute(_,$d^{q# K N}gma_{K n \alpha} gnnm_{N}^{k l}->0$)
substitute(_,$d^{m# K L}gnnm_{K}^{ m1 m2 }gnnm_{L}^{ k l }->s5*s2 /20*\epsilon^{m# m1 m2 k l}$)


substitute(_,$d^{m# M K}gnnm_{K}^{ m1 m2 }E_{M}^{ C# }->s5*s2 /20*E_{k l}^{ C# }\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# M K}gnnm_{K}^{ m1 m2 }\partial^{B??}{E_{M}^{ C }}->s5*s2 /20*\partial^{B??}{E_{k l}^{ C }}\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# M K}gnnm_{K}^{ m1 m2 }\partial_{B??}{E_{M}^{ C }}->s5*s2 /20*\partial_{B??}{E_{k l}^{ C }}\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# K M}gnnm_{K}^{ m1 m2 }E_{M}^{ C# }->s5*s2 /20*E_{k l}^{ C# }\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# K M}gnnm_{K}^{ m1 m2 }\partial^{B??}{E_{M}^{ C }}->s5*s2 /20*\partial^{B??}{E_{k l}^{ C }}\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# K M}gnnm_{K}^{ m1 m2 }\partial_{B??}{E_{M}^{ C }}->s5*s2 /20*\partial_{B??}{E_{k l}^{ C }}\epsilon^{m# m1 m2 k l}$)
substitute(_,$d^{m# K M}ga_{K \alpha# }\partial^{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }\partial^{B??}{E^{n \beta E# }}$)
substitute(_,$d^{m# K M}ga_{K \alpha# }\partial_{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }\partial_{B??}{E^{n \beta E# }}$)
substitute(_,$d^{m# K M}ga_{K \alpha# }E_{M}^{ E# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }E^{ n \beta E# }$)

substitute(_,$d^{m# M K}ga_{K \alpha# }\partial^{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }\partial^{B??}{E^{n \beta E# }}$)
substitute(_,$d^{m# M K}ga_{K \alpha# }\partial_{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }\partial_{B??}{E^{n \beta E# }}$)
substitute(_,$d^{m# M K}ga_{K \alpha# }E_{M}^{ E# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\beta \alpha# }E^{n \beta E# }$)
#
substitute(_,$d^{m# N M}gma_{N n \alpha# }E_{M}^{ E# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\alpha# \beta  }E^{ \beta  E# }$)
substitute(_,$d^{m# M N}gma_{N n \alpha# }E_{M}^{ E# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\alpha# \beta  }E^{ \beta  E# }$)
substitute(_,$d^{m# N M}gma_{N n \alpha# }\partial_{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\alpha# \beta  }\partial_{B??}{E^{ \beta  E# }}$)
substitute(_,$d^{m# M N}gma_{N n \alpha# }\partial_{B??}{E_{M}^{ E# }}->s5*s2 /10*\delta^{m#}_{n}\epsilon_{\alpha# \beta  }\partial_{B??}{E^{ \beta  E# }}$)
#
substitute(_,$d^{m# N K}gma_{N n \gamma# }ga_{K  \alpha# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{ \gamma# \alpha#   }$)
substitute(_,$d^{m# K N}gma_{N n \gamma# }ga_{K  \alpha# }->s5*s2 /10*\delta^{m#}_{n}\epsilon_{ \gamma# \alpha#   }$)
#
substitute(_,$E_{N}^{E#}gm_{n#}^{N}->E_{n#}^{E#}$)
substitute(_,$E_{N}^{E#}ga^{\beta# n# N}->E^{ n# \beta# E#}$)
substitute(_,$E_{N}^{E#}gm_{p#}^{N}->E_{p#}^{E#}$)
substitute(_,$E_{N}^{E#}ga^{\beta# p# N}->E^{p# \beta# E#}$)
substitute(_,$\partial^{B??}{E_{N}^{E#}}gm_{n#}^{N}->\partial^{B??}{E_{n#}^{E#}}$)
substitute(_,$\partial^{B??}{E_{N}^{E#}}ga^{\beta# n# N}->\partial^{B??}{E^{ n# \beta# E#}}$)
substitute(_,$\partial_{B??}{E_{N}^{E#}}gm_{n#}^{N}->\partial_{B??}{E_{n#}^{E#}}$)
substitute(_,$\partial_{B??}{E_{N}^{E#}}ga^{\beta# n# N}->\partial_{B??}{E^{ n# \beta# E#}}$)
substitute(_,$E^{M}_{A} gma_{M n \alpha} -> E_{n \alpha A}$)
substitute(_,$E_{M}^{A#} gma^{n# \alpha# M } -> E^{n# \alpha# A#}$)
substitute(_,$E^{M}_{A} gnnm_{M}^{ m n} -> E^{m n}_{ A}$)
substitute(_,$E_{M}^{A} gnnm^{M}_{ m n} -> E_{m n}^{ A}$)
substitute(_,$E_{M}^{A} gnnm_{ m n}^{M} -> E_{m n}^{ A}$)
substitute(_,$E^{M}_{A} ga_{M \alpha}->E_{\alpha A}$)
substitute(_,$E_{M}^{A} ga^{M \alpha}->E^{\alpha  A}$)

substitute(_,$\partial_{B??}{E^{M}_{A}} gma_{M n \alpha} -> \partial_{B??}{E_{n \alpha A}}$)
substitute(_,$\partial_{B??}{E^{M}_{A}} gnnm_{M}^{ m n} -> \partial_{B??}{E^{m n}_{ A}}$)
substitute(_,$\partial_{B??}{E^{M}_{A}} ga_{M \alpha}->\partial_{B??}{E_{\alpha A}}$)

substitute(_,$\partial_{B??}{E_{M}^{A}} gma^{M n \alpha} -> \partial_{B??}{E^{n \alpha A}}$)
substitute(_,$\partial_{B??}{E_{M}^{A}} gnnm_{ m n}^{M} -> \partial_{B??}{E_{m n}^{ A}$)
substitute(_,$\partial_{B??}{E_{M}^{A}} ga^{M \alpha}->\partial_{B??}{E^{\alpha A}}$)
eliminate_kronecker(_)
rename_dummies(_)
sort_product(_)
substitute(_,$E_{M}^{A#} gma^{n# \alpha# M } -> E^{n# \alpha# A#}$)
substitute(_,$\partial_{B??}{E_{M}^{A#}} gma^{n# \alpha# M } -> \partial_{B??}{E^{n# \alpha# A#}$);
# Out:
# ${}\frac{1}{2}E_{m}\,^{E} E^{\alpha C} \epsilon_{\beta \alpha} \partial_{n}\left(Om^{n \beta m}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{4}E_{m}\,^{E} E_{n k}\,^{C} \epsilon^{q l p n k} \partial_{q}\left(Om_{l p}\,^{m}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{2}E_{m}\,^{E} E^{n \alpha C} \epsilon_{\alpha \beta} \partial_{n}\left(Om^{m \beta}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{4}E_{n k}\,^{C} E^{m \alpha E} \epsilon^{q l p n k} \partial_{q}\left(Om_{l p m \alpha}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{2}E^{m \alpha E} E^{n \beta C} \epsilon_{\beta \gamma} \partial_{n}\left(Om^{\gamma}\,_{m \alpha}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{2}E_{m n}\,^{E} E^{k \alpha C} \epsilon_{\alpha \beta} \partial_{k}\left(Om^{\beta m n}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{2}E^{\alpha C} Om^{n \beta m} \epsilon_{\beta \alpha} \partial_{n}{E_{m}\,^{E}} d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{4}E_{n k}\,^{C} Om_{l p}\,^{m} \epsilon
# ...

# %%
# substituting of precise view of four-vector deformation tensor, s2 and s5 symbolic representation of sqrt2 and sqrt5
###
substitute(_,$Om^{m \alpha n}->0$)
substitute(_,$Om_{m1 m2}^{n}-> (s2/12)*\epsilon_{m1 m2 n1 n2 n3}Do^{n1 n2 n3 n}$)
substitute(_,$Om^{ n  \alpha}->0$)
substitute(_,$Om_{ l p m  \beta}-> 0$)
substitute(_,$Om^{ \gamma}_{ m  \alpha}-> -(1/24)*\delta^{\gamma}_{\alpha}\epsilon_{m n1 n2 n3 n4}Do^{n1 n2 n3 n4}$)
substitute(_,$Om^{\beta m n}->0$)
product_rule(_)
distribute(_)
distribute(_)
distribute(_)
substitute(_,$\partial_{A??}{s2} -> 0$)
substitute(_,$\partial^{A??}{s2} -> 0$)
substitute(_,$\partial_{A??}{s5} -> 0$)
substitute(_,$\partial^{A??}{s5} -> 0$)
substitute(_,$\partial_{A??}{\epsilon{#}} -> 0$)
substitute(_,$\partial^{A??}{\epsilon{#}} -> 0$)
substitute(_,$\partial_{A??}{\delta{#}} -> 0$)
substitute(_,$\partial^{A??}{\delta{#}} -> 0$)
substitute(_,$\partial^{A??}{\delta_{\alpha#}^{\beta#}}->0$)
substitute(_,$\partial^{A??}{\epsilon_{n# p# k# l# m#}}->0$)
substitute(_,$s2*s2->2$)
substitute(_,$s5*s5->5$)
eliminate_kronecker(_)
sort_product(_)
rename_dummies(_)
canonicalise(_);
# Out:
# ${}\frac{1}{24}E_{k}\,^{E} E_{l m}\,^{C} \epsilon_{n p q r t} \epsilon^{l m n p u} \partial_{u}\left(Do^{q r t k}\right) d_{A B E} e_{mod} {s_{5}} - \frac{1}{48}E^{k \alpha C} E^{l \beta E} \epsilon_{\alpha \beta} \epsilon_{l m n p q} \partial_{k}\left(Do^{m n p q}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{24}Do^{k l m n} E_{p q}\,^{C} \epsilon_{k l m r t} \epsilon^{p q r t u} \partial_{u}{E_{n}\,^{E}} d_{A B E} e_{mod} {s_{5}} - \frac{1}{48}Do^{k l m n} E^{p \alpha C} \epsilon_{\alpha \beta} \epsilon_{k l m n q} \partial_{p}{E^{q \beta E}} d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{24}Do^{k l m n} E_{n}\,^{C} \epsilon_{k l m p q} \epsilon^{p q r t u} \partial_{r}{E_{t u}\,^{E}} d_{A B E} e_{mod} {s_{5}}+\frac{1}{48}Do^{k l m n} E^{p \alpha C} \epsilon_{\alpha \beta} \epsilon_{k l m n p} \partial_{q}{E^{q \beta E}} d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{288}Do^{k l m {m_{1}}} E_{{m_{1}}}\,^{C} E_{{m_{2}}}\,^{E} \epsilon_{k l m {m_{3}} n} \epsilon_{p q r t u} \epsilon^{{m_
# ...

# %%
#substituting of four-vector of deformation:
###
substitute(_,$Do^{m p1 p2 p3}->\rho^{i1 i2 i3 i4} k_{i1}^{m}k_{i2}^{p1}k_{i3}^{p2}k_{i4}^{p3}$);
# Out:
# ${}\frac{1}{24}E_{k}\,^{E} E_{l m}\,^{C} \epsilon_{n p q r t} \epsilon^{l m n p u} \partial_{u}\left(\rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} k_{{i_{1}}}\,^{q} k_{{i_{2}}}\,^{r} k_{{i_{3}}}\,^{t} k_{{i_{4}}}\,^{k}\right) d_{A B E} e_{mod} {s_{5}} - \frac{1}{48}E^{k \alpha C} E^{l \beta E} \epsilon_{\alpha \beta} \epsilon_{l m n p q} \partial_{k}\left(\rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} k_{{i_{1}}}\,^{m} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{p} k_{{i_{4}}}\,^{q}\right) d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{24}\rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} k_{{i_{1}}}\,^{k} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{n} E_{p q}\,^{C} \epsilon_{k l m r t} \epsilon^{p q r t u} \partial_{u}{E_{n}\,^{E}} d_{A B E} e_{mod} {s_{5}} - \frac{1}{48}\rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} k_{{i_{1}}}\,^{k} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{n} E^{p \alpha C} \epsilon_{\alpha \beta} \epsilon_{k l m n q} \partial_{p}{E^{q \beta E}} d_{A B E} e_{mod} {s_{2}} {s_{5}}+\frac{1}{24}\rho^
# ...

# %%
# action of derivative and epsilon tensors to generalised deltas
###
product_rule(_)
distribute(_)
substitute(_,$\partial_{A??}{tdk{#}} -> 0$)
substitute(_,$\partial_{A??}{\epsilon{#}} -> 0$)
substitute(_,$\partial^{A??}{\epsilon{#}} -> 0$)
substitute(_,$\partial_{A??}{\rho{#}} -> 0$)
substitute(_,$\partial^{A??}{\rho{#}} -> 0$)
substitute(_,$\partial_{A??}{s2} -> 0$)
substitute(_,$\partial^{A??}{s2} -> 0$)
substitute(_,$\partial_{A??}{s5} -> 0$)
substitute(_,$\partial_{A??}{var1} -> 0$)
substitute(_,$\partial_{A??}{var2} -> 0$)
substitute(_,$\partial_{A??}{var3} -> 0$)
substitute(_,$\partial_{A??}{var4} -> 0$)
substitute(_,$\partial_{A??}{var5} -> 0$)
substitute(_,$\partial_{A??}{var6} -> 0$)
substitute(_,$\partial^{A??}{s5} -> 0$)
rename_dummies(_)
canonicalise(_)
sort_product(_)
substitute(_,$\epsilon_{ m1 n1 p1 p q}\epsilon^{ p q m2 n2 p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 t u}\epsilon^{ m2 n2 t u p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 t u}\epsilon^{ m2 n2 t u p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 n p}\epsilon^{ m2 n2 p2 n p}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon^{l m n p q} \epsilon_{ n p r t u }->12\delta_{r}^{l}_{t}^{m}_{u}^{q}$)
substitute(_,$\epsilon_{ m1 n1 p1 p q}\epsilon^{ p q m2 n2 p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 t u}\epsilon^{ m2 n2 t u p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 t u}\epsilon^{ m2 n2 t u p2}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{ m1 n1 p1 n p}\epsilon^{ m2 n2 p2 n p}->12\delta_{m1}^{m2}_{n1}^{n2}_{p1}^{p2}$)
substitute(_,$\epsilon_{l p q r t}\epsilon^{ m n p q u}->12\delta_{l}^{m}_{r}^{n}_{t}^{u}$)
substitute(_,$\epsilon_{k l q r t} \epsilon^{n p q r u}->12\delta_{k}^{n}_{l}^{p}_{t}^{u}$)
substitute(_,$\epsilon_{l m1 m2 n p}\epsilon^{ m1 m2 q r t}->12\delta_{l}^{q}_{n}^{r}_{p}^{t}$)
expand_delta(_)
distribute(_)
eliminate_kronecker(_)
rename_dummies(_)
sort_product(_)
\epsilon^{i1 i2 i3 i4}::AntiSymmetric:
eliminate_kronecker(_)
sort_product(_)
rename_dummies(_)
canonicalise(_);
# Out:
# ${}\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{n}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{n}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}
# ...

# %%
#change of action of derivative through veilbeins from veilbeins to derivative through killing vectors from veilbeins
###

substitute(_,$\epsilon_{k l m p q}\partial_{n}{E^{n \gamma E}}-> \epsilon_{ l m p q n}\partial_{k}{E^{n \gamma E}}-\epsilon_{ m p q n k}\partial_{l}{E^{n \gamma E}}+\epsilon_{ p q n k l}\partial_{m}{E^{n \gamma E}}-\epsilon_{ q n k l m}\partial_{p}{E^{n \gamma E}}+\epsilon_{ n k l m p}\partial_{q}{E^{n \gamma E}}$)

distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)

substitute(_,$E^{k \alpha C} \partial_{k}{e_{mod}}\epsilon_{l m n p q}->1/2*(-E^{k \alpha C} \partial_{m}{e_{mod}}\epsilon_{n p q k l}+E^{k \alpha C} \partial_{n}{e_{mod}}\epsilon_{p q k l m}-E^{k \alpha C} \partial_{p}{e_{mod}}\epsilon_{q k l m n}+E^{k \alpha C} \partial_{q}{e_{mod}}\epsilon_{k l m n p})$);
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
sort_product(_)

;
# Out:
# ${}\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{n}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{n}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{l} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}
# ...

# %%
#change of action of derivative from veilbeins components to Killing vectors components
###
substitute(_,$k_{i#}^{l}\partial_{l}{E_{m n}^{E#}}->1*E_{m n}^{E#}\partial_{l}{k_{i#}^{l}}+E_{ n l}^{E#}\partial_{m}{k_{i#}^{l}}+E_{ l m}^{E#}\partial_{n}{k_{i#}^{l}}$)
substitute(_,$k_{i#}^{l}\partial_{l}{E^{m n}_{E#}}->-E^{m n}_{E#}\partial_{l}{k_{i#}^{l}}-E^{ n l}_{E#}\partial_{l}{k_{i#}^{m}}-E^{  l m}_{E#}\partial_{l}{k_{i#}^{n}}$)
substitute(_,$\partial_{q}{e_{mod}} k_{i#}^{q}->-e_{mod}\partial_{q}{k_{i#}^{q}}$)
substitute(_,$k_{i#}^{m}\partial_{m}{E^{n}_{A}}->E^{m}_{A}\partial_{m}{k_{i#}^{n}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$k_{i#}^{m}\partial_{m}{E_{n}^{A}}->-E_{m}^{A}\partial_{n}{k_{i#}^{ m}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$\partial_{q}{e5} k_{i#}^{q}->- 5/3*e5\partial_{q}{k_{i#}^{q}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$k_{i#}^{n}\partial_{n}{E_{ m# \beta# A}}->-E_{ n \beta# A}\partial_{m#}{k_{i#}^{ n}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$k_{i#}^{n}\partial_{n}{E^{ m# \beta# A}}->E^{ n \beta# A}\partial_{n}{k_{i#}^{ m#}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$k_{i#}^{n}\partial_{n}{E^{\alpha E}}->\partial_{n}{k_{i#}^{n}}E^{\alpha E}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
sort_product(_)
;
# Out:
# ${}\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{3}} {i_{1}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}
# ...

# %%
#killing of \partial_{m}{k_{i}^{m}} terms
###
substitute(_,$\epsilon_{k l m n p}\partial_{q}{k_{i#}^{q}}->\epsilon_{l m n p q}\partial_{k}{k_{i#}^{q}}-\epsilon_{m n p q k}\partial_{l}{k_{i#}^{q}}+\epsilon_{n p q k l}\partial_{m}{k_{i#}^{q}}-\epsilon_{p q k l m}\partial_{n}{k_{i#}^{q}}+\epsilon_{q k l m n}\partial_{p}{k_{i#}^{q}}$)
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
;
# Out:
# ${}\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{1}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{n} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}{k_{{i_{1}}}\,^{l}} \rho^{{i_{2}} {i_{3}} {i_{1}} {i_{4}}} d_{A B E} e_{mod} k_{{i_{2}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{4}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{l m}\,^{C} \partial_{n}
# ...

# %%
#adding structure constants
###
substitute(_,$k_{i8}^{t}\partial_{t}{k_{i1}^{l}}->1/2*f_{i8 i1}^{i9}k_{i9}^{l}$)
f_{i8 i1}^{i9}::TableauSymmetry(shape={1,1}, indices={0,1})
distribute(_)
sort_product(_)
rename_dummies(_)
canonicalise(_)
substitute(_,$s2 s2->2$)
substitute(_,$s5 s5->5$)
rename_dummies(_)
sort_product(_)
canonicalise(_);
# Out:
# ${}\frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} f_{{i_{1}} {i_{3}}}\,^{{i_{5}}} k_{{i_{2}}}\,^{m} k_{{i_{4}}}\,^{k} k_{{i_{5}}}\,^{n} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} f_{{i_{1}} {i_{2}}}\,^{{i_{5}}} k_{{i_{3}}}\,^{m} k_{{i_{4}}}\,^{k} k_{{i_{5}}}\,^{n} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} f_{{i_{2}} {i_{3}}}\,^{{i_{5}}} k_{{i_{1}}}\,^{m} k_{{i_{4}}}\,^{k} k_{{i_{5}}}\,^{n} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} f_{{i_{3}} {i_{4}}}\,^{{i_{5}}} k_{{i_{1}}}\,^{m} k_{{i_{2}}}\,^{n} k_{{i_{5}}}\,^{k} {s_{5}} - \frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}} {i_{2}} {i_{3}} {i_{4}}} d_{A B E} e_{mod} f_{{i_{2}} {i_{4}}}\,^{{i_{5}}} k_{{i_{1}}}\,^{m} k_{{i_{3}}}\,^{n} k_{{i_{5}}}\,^{k} {s_{5}}+\frac{1}{6}E_{k}\,^{E} E_{m n}\,^{C} \rho^{{i_{1}
# ...
